# %%
import random

class NakliLLM:
    def __init__(self):
        print('LLM Created')

    def predict(self,prompt):
        response_list = [
            'Delhi is the capital of india',
            'IPL is stupid in india',
            'AI is going to take all jobs'
        ]
        return {'response':random.choice(response_list)}

# %%
class NakliPromptTemplate:
    def __init__(self,template,input_variables):
        self.template = template
        self.input_variables = input_variables
        
    def format(self,input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template='write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
prompt = template.format({'length':'short','topic':'india'})

# %%
llm = NakliLLM()
# Out:
# LLM Created

# %%
llm.predict(prompt)
# Out:
# {'response': 'Delhi is the capital of india'}

# %%
class NakliLLMChain:
    def __init__(self,prompt,llm):
        self.llm = llm
        self.prompt = prompt

    def run(self,input_dict):
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)
        print(result)
        return result['response']

# %%
template = NakliPromptTemplate(
    template='write a {length} poem about {topic}',
    input_variables=['length','topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM Created

# %%
chain = NakliLLMChain(llm,template)

# %%
chain.run({'length':'short','topic':'india'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 chain.run({'length':'short','topic':'india'})
#
# Cell In[53], line 7, in NakliLLMChain.run(self, input_dict)
#       6     def run(self,input_dict):
# ----> 7         final_prompt = self.prompt.format(input_dict)
#       8         result = self.llm.predict(final_prompt)
#       9         print(result)
#      10         return result['response']
#
# AttributeError: 'NakliLLM' object has no attribute 'format'
